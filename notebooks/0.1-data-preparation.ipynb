# %% [markdown]
# # Dataset combination
# Dataset source:
# [European Environmental Agency](https://www.eea.europa.eu/data-and-maps/data/aqereporting-9)
#
# Dataset will combine data of PM10, PM2.5, CO, C6H6, SO2 and NO2 measurements in years 2018-2021 (measured in Bratislava, Slovakia) from their respective CSV files.

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df_2018 = pd.read_csv('../data/raw/EEA-SK-Bratislava/2018/SK_5_27208_2018_timeseries_PM10.csv')
df_2018.rename(columns={'Concentration': 'PM10 Concentration', 'UnitOfMeasurement': 'PM10 Unit'}, inplace=True)
df_pm2_5_2018 = pd.read_csv('../data/raw/EEA-SK-Bratislava/2018/SK_6001_35900_2018_timeseries_PM25.csv')
df_pm2_5_2018.rename(columns={'Concentration': 'PM2.5 Concentration', 'UnitOfMeasurement': 'PM2.5 Unit'}, inplace=True)
df_pm2_5_2018 = df_pm2_5_2018[['DatetimeBegin', 'DatetimeEnd', 'PM2.5 Concentration', 'PM2.5 Unit']]
df_2018 = pd.merge(df_2018, df_pm2_5_2018, how='outer')
df_co_2018 = pd.read_csv('../data/raw/EEA-SK-Bratislava/2018/SK_10_27210_2018_timeseries_CO.csv')
df_co_2018.rename(columns={'Concentration': 'CO Concentration', 'UnitOfMeasurement': 'CO Unit'}, inplace=True)
df_co_2018 = df_co_2018[['DatetimeBegin', 'DatetimeEnd', 'CO Concentration', 'CO Unit']]
df_2018 = pd.merge(df_2018, df_co_2018, how='outer')
df_no2_2018 = pd.read_csv('../data/raw/EEA-SK-Bratislava/2018/SK_8_27323_2018_timeseries_NO2.csv')
df_no2_2018.rename(columns={'Concentration': 'NO2 Concentration', 'UnitOfMeasurement': 'NO2 Unit'}, inplace=True)
df_no2_2018 = df_no2_2018[['DatetimeBegin', 'DatetimeEnd', 'NO2 Concentration', 'NO2 Unit']]
df_2018 = pd.merge(df_2018, df_no2_2018, how='outer')
df_so2_2018 = pd.read_csv('../data/raw/EEA-SK-Bratislava/2018/SK_1_27236_2018_timeseries_SO2.csv')
df_so2_2018.rename(columns={'Concentration': 'SO2 Concentration', 'UnitOfMeasurement': 'SO2 Unit'}, inplace=True)
df_so2_2018 = df_so2_2018[['DatetimeBegin', 'DatetimeEnd', 'SO2 Concentration', 'SO2 Unit']]
df_2018 = pd.merge(df_2018, df_so2_2018, how='outer')
df_c6h6_2018 = pd.read_csv('../data/raw/EEA-SK-Bratislava/2018/SK_20_27277_2018_timeseries_C6H6.csv')
df_c6h6_2018.rename(columns={'Concentration': 'C6H6 Concentration', 'UnitOfMeasurement': 'C6H6 Unit'}, inplace=True)
df_c6h6_2018 = df_c6h6_2018[['DatetimeBegin', 'DatetimeEnd', 'C6H6 Concentration', 'C6H6 Unit']]
df_2018 = pd.merge(df_2018, df_c6h6_2018, how='outer')
df_2018.drop(columns=['Countrycode', 'Namespace', 'AirQualityNetwork', 'AirQualityStation', 'SamplingPoint', 'SamplingProcess', 'Sample', 'AveragingTime', 'AirPollutantCode', 'AirPollutant', 'AirQualityStationEoICode', 'Validity', 'Verification'], inplace=True)
df_2018
# Out:
#       PM10 Concentration PM10 Unit               DatetimeBegin  \
# 0                38.9420     µg/m3  2018-01-01 00:00:00 +01:00
# 1                52.8890     µg/m3  2018-01-01 01:00:00 +01:00
# 2                37.0070     µg/m3  2018-01-01 02:00:00 +01:00
# 3                35.8370     µg/m3  2018-01-01 03:00:00 +01:00
# 4                34.4080     µg/m3  2018-01-01 04:00:00 +01:00
# ...                  ...       ...                         ...
# 8755              9.7028     µg/m3  2018-12-31 19:00:00 +01:00
# 8756             16.8660     µg/m3  2018-12-31 20:00:00 +01:00
# 8757             20.2520     µg/m3  2018-12-31 21:00:00 +01:00
# 8758             20.4290     µg/m3  2018-12-31 22:00:00 +01:00
# 8759             26.8050     µg/m3  2018-12-31 23:00:00 +01:00
#
#                      DatetimeEnd  PM2.5 Concentration PM2.5 Unit  \
# 0     2018-01-01 01:00:00 +01:00               46.409      µg/m3
# 1     2018-01-01 02:00:00 +01:00               53.467      µg/m3
# 2     2018-01-01 03:00:00 +01:00               37.668      µg/m3
# 3     2018-01-01 04:00:00 +01:00               37.333      µg/m3
# 4     2018-01-01 05:00:00 +01:00               29.130      µg/m3
# ...                          ...                  ...        ...
# 8755  2018-12-31 20:00:00 +01:00               18.187      µg/m3
# 8756  2018-12-31 21:00:00 +01:00               18.517      µg/m3
# 8757  2018-12-31 22:00:00 +01:00               20.549      µg/m3
# 8758  2018-12-31 23:00:00 +01:00               26.334      µg/m3
# 8759  2019-01-01 00:00:00 +01:00               25.724      µg/m3
#
#       CO Concentration CO Unit  NO2 Concentration NO2 Unit  SO2 Concentration  \
# 0              0.46168   mg/m3            21.6056    µg/m3            5.36549
# 1              0.43268   mg/m3            21.1869    µg/m3                NaN
# 2              0.39208   mg/m3            16.2845    µg/m3            5.14364
# 3              0.38628   mg/m3            17.3246    µg/m3            5.16466
# 4              0.36308   mg/m3            15.5656    µg/m3            5.23302
# ...                ...     ...                ...      ...                ...
# 8755           0.31900   mg/m3            39.7811    µg/m3            7.56318
# 8756           0.32364   mg/m3            39.3738    µg/m3            6.60451
# 8757           0.34684   mg/m3            39.9206    µg/m3            7.36421
# 8758           0.36076   mg/m3            37.2725    µg/m3            6.49599
# 8759           0.36192   mg/m3            39.9646    µg/m3            4.86408
#
#      SO2 Unit  C6H6 Concentration C6H6 Unit
# 0       µg/m3             1.10825     µg/m3
# 1         NaN             0.93600     µg/m3
# 2       µg/m3             0.69225     µg/m3
# 3       µg/m3             0.59800     µg/m3
# 4       µg/m3             0.57200     µg/m3
# ...       ...                 ...       ...
# 8755    µg/m3             0.37375     µg/m3
# 8756    µg/m3             0.39325     µg/m3
# 8757    µg/m3             0.51025     µg/m3
# 8758    µg/m3             0.45825     µg/m3
# 8759    µg/m3             0.46475     µg/m3
#
# [8760 rows x 14 columns]

# %%
df_2019 = pd.read_csv('../data/raw/EEA-SK-Bratislava/2019/SK_5_27294_2019_timeseries_PM10.csv')
df_2019.rename(columns={'Concentration': 'PM10 Concentration', 'UnitOfMeasurement': 'PM10 Unit'}, inplace=True)
df_pm2_5_2019 = pd.read_csv('../data/raw/EEA-SK-Bratislava/2019/SK_6001_35900_2019_timeseries_PM25.csv')
df_pm2_5_2019.rename(columns={'Concentration': 'PM2.5 Concentration', 'UnitOfMeasurement': 'PM2.5 Unit'}, inplace=True)
df_pm2_5_2019 = df_pm2_5_2019[['DatetimeBegin', 'DatetimeEnd', 'PM2.5 Concentration', 'PM2.5 Unit']]
df_2019 = pd.merge(df_2019, df_pm2_5_2019, how='outer')
df_co_2019 = pd.read_csv('../data/raw/EEA-SK-Bratislava/2019/SK_10_27210_2019_timeseries_CO.csv')
df_co_2019.rename(columns={'Concentration': 'CO Concentration', 'UnitOfMeasurement': 'CO Unit'}, inplace=True)
df_co_2019 = df_co_2019[['DatetimeBegin', 'DatetimeEnd', 'CO Concentration', 'CO Unit']]
df_2019 = pd.merge(df_2019, df_co_2019, how='outer')
df_no2_2019 = pd.read_csv('../data/raw/EEA-SK-Bratislava/2019/SK_8_27323_2019_timeseries_NO2.csv')
df_no2_2019.rename(columns={'Concentration': 'NO2 Concentration', 'UnitOfMeasurement': 'NO2 Unit'}, inplace=True)
df_no2_2019 = df_no2_2019[['DatetimeBegin', 'DatetimeEnd', 'NO2 Concentration', 'NO2 Unit']]
df_2019 = pd.merge(df_2019, df_no2_2019, how='outer')
df_so2_2019 = pd.read_csv('../data/raw/EEA-SK-Bratislava/2019/SK_1_27236_2019_timeseries_SO2.csv')
df_so2_2019.rename(columns={'Concentration': 'SO2 Concentration', 'UnitOfMeasurement': 'SO2 Unit'}, inplace=True)
df_so2_2019 = df_so2_2019[['DatetimeBegin', 'DatetimeEnd', 'SO2 Concentration', 'SO2 Unit']]
df_2019 = pd.merge(df_2019, df_so2_2019, how='outer')
df_c6h6_2019 = pd.read_csv('../data/raw/EEA-SK-Bratislava/2019/SK_20_27277_2019_timeseries_C6H6.csv')
df_c6h6_2019.rename(columns={'Concentration': 'C6H6 Concentration', 'UnitOfMeasurement': 'C6H6 Unit'}, inplace=True)
df_c6h6_2019 = df_c6h6_2019[['DatetimeBegin', 'DatetimeEnd', 'C6H6 Concentration', 'C6H6 Unit']]
df_2019 = pd.merge(df_2019, df_c6h6_2019, how='outer')
df_2019.drop(columns=['Countrycode', 'Namespace', 'AirQualityNetwork', 'AirQualityStation', 'SamplingPoint', 'SamplingProcess', 'Sample', 'AveragingTime', 'AirPollutantCode', 'AirPollutant', 'AirQualityStationEoICode', 'Validity', 'Verification'], inplace=True)
df_2019
# Out:
#       PM10 Concentration PM10 Unit               DatetimeBegin  \
# 0               116.6100     µg/m3  2019-01-01 00:00:00 +01:00
# 1               126.7300     µg/m3  2019-01-01 01:00:00 +01:00
# 2                54.7150     µg/m3  2019-01-01 02:00:00 +01:00
# 3                40.2230     µg/m3  2019-01-01 03:00:00 +01:00
# 4                33.2880     µg/m3  2019-01-01 04:00:00 +01:00
# ...                  ...       ...                         ...
# 8753              9.9199     µg/m3  2019-12-31 19:00:00 +01:00
# 8754              9.2445     µg/m3  2019-12-31 20:00:00 +01:00
# 8755             14.9470     µg/m3  2019-12-31 21:00:00 +01:00
# 8756             13.9920     µg/m3  2019-12-31 22:00:00 +01:00
# 8757             13.3540     µg/m3  2019-12-31 23:00:00 +01:00
#
#                      DatetimeEnd  PM2.5 Concentration PM2.5 Unit  \
# 0     2019-01-01 01:00:00 +01:00             106.1900      µg/m3
# 1     2019-01-01 02:00:00 +01:00             108.0900      µg/m3
# 2     2019-01-01 03:00:00 +01:00              45.8930      µg/m3
# 3     2019-01-01 04:00:00 +01:00              37.3770      µg/m3
# 4     2019-01-01 05:00:00 +01:00              27.3940      µg/m3
# ...                          ...                  ...        ...
# 8753  2019-12-31 20:00:00 +01:00               8.6867      µg/m3
# 8754  2019-12-31 21:00:00 +01:00              15.7980      µg/m3
# 8755  2019-12-31 22:00:00 +01:00              12.1420      µg/m3
# 8756  2019-12-31 23:00:00 +01:00              14.9140      µg/m3
# 8757  2020-01-01 00:00:00 +01:00              14.7340      µg/m3
#
#       CO Concentration CO Unit  NO2 Concentration NO2 Unit  SO2 Concentration  \
# 0             0.374680   mg/m3            45.9664    µg/m3            7.70150
# 1             0.406000   mg/m3            45.3469    µg/m3                NaN
# 2             0.450080   mg/m3            46.4387    µg/m3            7.61398
# 3             0.481400   mg/m3            51.4309    µg/m3            7.90020
# 4             0.488360   mg/m3            44.0487    µg/m3            5.86956
# ...                ...     ...                ...      ...                ...
# 8753          0.238612   mg/m3            18.0629    µg/m3           -1.84072
# 8754          0.254388   mg/m3            17.2298    µg/m3           -1.64920
# 8755          0.271788   mg/m3            17.3067    µg/m3           -1.64122
# 8756          0.229796   mg/m3            12.7850    µg/m3           -1.34330
# 8757          0.231884   mg/m3            11.2554    µg/m3           -1.04804
#
#      SO2 Unit  C6H6 Concentration C6H6 Unit
# 0       µg/m3            0.513500     µg/m3
# 1         NaN            0.601250     µg/m3
# 2       µg/m3            0.637000     µg/m3
# 3       µg/m3            0.724750     µg/m3
# 4       µg/m3            0.630500     µg/m3
# ...       ...                 ...       ...
# 8753    µg/m3            0.427050     µg/m3
# 8754    µg/m3            0.382200     µg/m3
# 8755    µg/m3            0.429975     µg/m3
# 8756    µg/m3            0.479050     µg/m3
# 8757    µg/m3            0.444600     µg/m3
#
# [8758 rows x 14 columns]

# %%
df_2020 = pd.read_csv('../data/raw/EEA-SK-Bratislava/2020/SK_5_27294_2020_timeseries_PM10_1.csv')
df_2020.rename(columns={'Concentration': 'PM10 Concentration', 'UnitOfMeasurement': 'PM10 Unit'}, inplace=True)
df_pm2_5_2020 = pd.read_csv('../data/raw/EEA-SK-Bratislava/2020/SK_6001_35900_2020_timeseries_PM25_1.csv')
df_pm2_5_2020.rename(columns={'Concentration': 'PM2.5 Concentration', 'UnitOfMeasurement': 'PM2.5 Unit'}, inplace=True)
df_pm2_5_2020 = df_pm2_5_2020[['DatetimeBegin', 'DatetimeEnd', 'PM2.5 Concentration', 'PM2.5 Unit']]
df_2020 = pd.merge(df_2020, df_pm2_5_2020, how='outer')
df_co_2020 = pd.read_csv('../data/raw/EEA-SK-Bratislava/2020/SK_10_27210_2020_timeseries_CO.csv')
df_co_2020.rename(columns={'Concentration': 'CO Concentration', 'UnitOfMeasurement': 'CO Unit'}, inplace=True)
df_co_2020 = df_co_2020[['DatetimeBegin', 'DatetimeEnd', 'CO Concentration', 'CO Unit']]
df_2020 = pd.merge(df_2020, df_co_2020, how='outer')
df_no2_2020 = pd.read_csv('../data/raw/EEA-SK-Bratislava/2020/SK_8_27303_2020_timeseries_NO2_1.csv')
df_no2_2020.rename(columns={'Concentration': 'NO2 Concentration', 'UnitOfMeasurement': 'NO2 Unit'}, inplace=True)
df_no2_2020 = df_no2_2020[['DatetimeBegin', 'NO2 Concentration', 'NO2 Unit']]
df_2020 = pd.merge(df_2020, df_no2_2020, how='outer')
df_so2_2020 = pd.read_csv('../data/raw/EEA-SK-Bratislava/2020/SK_1_27236_2020_timeseries_SO2.csv')
df_so2_2020.rename(columns={'Concentration': 'SO2 Concentration', 'UnitOfMeasurement': 'SO2 Unit'}, inplace=True)
df_so2_2020 = df_so2_2020[['DatetimeBegin', 'DatetimeEnd', 'SO2 Concentration', 'SO2 Unit']]
df_2020 = pd.merge(df_2020, df_so2_2020, how='outer')
df_c6h6_2020 = pd.read_csv('../data/raw/EEA-SK-Bratislava/2020/SK_20_27277_2020_timeseries_C6H6.csv')
df_c6h6_2020.rename(columns={'Concentration': 'C6H6 Concentration', 'UnitOfMeasurement': 'C6H6 Unit'}, inplace=True)
df_c6h6_2020 = df_c6h6_2020[['DatetimeBegin', 'DatetimeEnd', 'C6H6 Concentration', 'C6H6 Unit']]
df_2020 = pd.merge(df_2020, df_c6h6_2020, how='outer')
df_2020.drop(columns=['Countrycode', 'Namespace', 'AirQualityNetwork', 'AirQualityStation', 'SamplingPoint', 'SamplingProcess', 'Sample', 'AveragingTime', 'AirPollutantCode', 'AirPollutant', 'AirQualityStationEoICode', 'Validity', 'Verification'], inplace=True)
df_2020
# Out:
#       PM10 Concentration PM10 Unit               DatetimeBegin  \
# 0                 16.070     µg/m3  2020-01-01 00:00:00 +01:00
# 1                120.150     µg/m3  2020-01-01 01:00:00 +01:00
# 2                 52.513     µg/m3  2020-01-01 02:00:00 +01:00
# 3                 40.058     µg/m3  2020-01-01 03:00:00 +01:00
# 4                 26.224     µg/m3  2020-01-01 04:00:00 +01:00
# ...                  ...       ...                         ...
# 8782              30.728     µg/m3  2020-12-31 19:00:00 +01:00
# 8783              33.860     µg/m3  2020-12-31 20:00:00 +01:00
# 8784              34.019     µg/m3  2020-12-31 21:00:00 +01:00
# 8785              42.901     µg/m3  2020-12-31 22:00:00 +01:00
# 8786              61.445     µg/m3  2020-12-31 23:00:00 +01:00
#
#                      DatetimeEnd  PM2.5 Concentration PM2.5 Unit  \
# 0     2020-01-01 01:00:00 +01:00               14.328      µg/m3
# 1     2020-01-01 02:00:00 +01:00              118.520      µg/m3
# 2     2020-01-01 03:00:00 +01:00               45.789      µg/m3
# 3     2020-01-01 04:00:00 +01:00               38.463      µg/m3
# 4     2020-01-01 05:00:00 +01:00               18.477      µg/m3
# ...                          ...                  ...        ...
# 8782  2020-12-31 20:00:00 +01:00               29.426      µg/m3
# 8783  2020-12-31 21:00:00 +01:00               29.544      µg/m3
# 8784  2020-12-31 22:00:00 +01:00               31.430      µg/m3
# 8785  2020-12-31 23:00:00 +01:00               36.028      µg/m3
# 8786  2021-01-01 00:00:00 +01:00               49.494      µg/m3
#
#       CO Concentration CO Unit  NO2 Concentration NO2 Unit  SO2 Concentration  \
# 0             0.238960   mg/m3            23.4564    µg/m3          -0.148960
# 1             0.231304   mg/m3            23.4411    µg/m3           3.044640
# 2             0.250328   mg/m3            27.0777    µg/m3           1.219340
# 3             0.259724   mg/m3            30.7660    µg/m3           1.514070
# 4             0.256708   mg/m3            17.0418    µg/m3           1.529500
# ...                ...     ...                ...      ...                ...
# 8782          0.488592   mg/m3            29.6092    µg/m3           0.313348
# 8783          0.570372   mg/m3            32.5403    µg/m3           0.171570
# 8784          0.633824   mg/m3            33.5212    µg/m3           0.345534
# 8785          0.617816   mg/m3            36.9054    µg/m3           1.436400
# 8786          0.627328   mg/m3            32.9782    µg/m3           1.144330
#
#      SO2 Unit  C6H6 Concentration C6H6 Unit
# 0       µg/m3            0.409825     µg/m3
# 1       µg/m3            0.386100     µg/m3
# 2       µg/m3            0.385775     µg/m3
# 3       µg/m3            0.381550     µg/m3
# 4       µg/m3            0.366275     µg/m3
# ...       ...                 ...       ...
# 8782    µg/m3            1.727370     µg/m3
# 8783    µg/m3            1.545700     µg/m3
# 8784    µg/m3            1.986400     µg/m3
# 8785    µg/m3            2.013050     µg/m3
# 8786    µg/m3            1.663680     µg/m3
#
# [8787 rows x 14 columns]

# %%
df_2021 = pd.read_csv('../data/raw/EEA-SK-Bratislava/2021/SK_5_27208_2021_timeseries_PM10.csv')
df_2021.rename(columns={'Concentration': 'PM10 Concentration', 'UnitOfMeasurement': 'PM10 Unit'}, inplace=True)
df_pm2_5_2021 = pd.read_csv('../data/raw/EEA-SK-Bratislava/2021/SK_6001_45549_2021_timeseries_PM25.csv')
df_pm2_5_2021.rename(columns={'Concentration': 'PM2.5 Concentration', 'UnitOfMeasurement': 'PM2.5 Unit'}, inplace=True)
df_pm2_5_2021 = df_pm2_5_2021[['DatetimeBegin', 'DatetimeEnd', 'PM2.5 Concentration', 'PM2.5 Unit']]
df_2021 = pd.merge(df_2021, df_pm2_5_2021, how='outer')
df_co_2021 = pd.read_csv('../data/raw/EEA-SK-Bratislava/2021/SK_10_27210_2021_timeseries_CO.csv')
df_co_2021.rename(columns={'Concentration': 'CO Concentration', 'UnitOfMeasurement': 'CO Unit'}, inplace=True)
df_co_2021 = df_co_2021[['DatetimeBegin', 'DatetimeEnd', 'CO Concentration', 'CO Unit']]
df_2021 = pd.merge(df_2021, df_co_2021, how='outer')
df_no2_2021 = pd.read_csv('../data/raw/EEA-SK-Bratislava/2021/SK_8_27323_2021_timeseries_NO2.csv')
df_no2_2021.rename(columns={'Concentration': 'NO2 Concentration', 'UnitOfMeasurement': 'NO2 Unit'}, inplace=True)
df_no2_2021 = df_no2_2021[['DatetimeBegin', 'NO2 Concentration', 'NO2 Unit']]
df_2021 = pd.merge(df_2021, df_no2_2021, how='outer')
df_so2_2021 = pd.read_csv('../data/raw/EEA-SK-Bratislava/2021/SK_1_68662_2021_timeseries_SO2.csv')
df_so2_2021.rename(columns={'Concentration': 'SO2 Concentration', 'UnitOfMeasurement': 'SO2 Unit'}, inplace=True)
df_so2_2021 = df_so2_2021[['DatetimeBegin', 'DatetimeEnd', 'SO2 Concentration', 'SO2 Unit']]
df_2021 = pd.merge(df_2021, df_so2_2021, how='outer')
df_c6h6_2021 = pd.read_csv('../data/raw/EEA-SK-Bratislava/2021/SK_20_27277_2021_timeseries_C6H6.csv')
df_c6h6_2021.rename(columns={'Concentration': 'C6H6 Concentration', 'UnitOfMeasurement': 'C6H6 Unit'}, inplace=True)
df_c6h6_2021 = df_c6h6_2021[['DatetimeBegin', 'DatetimeEnd', 'C6H6 Concentration', 'C6H6 Unit']]
df_2021 = pd.merge(df_2021, df_c6h6_2021, how='outer')
df_2021.drop(columns=['Countrycode', 'Namespace', 'AirQualityNetwork', 'AirQualityStation', 'SamplingPoint', 'SamplingProcess', 'Sample', 'AveragingTime', 'AirPollutantCode', 'AirPollutant', 'AirQualityStationEoICode', 'Validity', 'Verification'], inplace=True)
df_2021
# Out:
#       PM10 Concentration PM10 Unit               DatetimeBegin  \
# 0                 43.873     µg/m3  2021-01-01 00:00:00 +01:00
# 1                 88.196     µg/m3  2021-01-01 01:00:00 +01:00
# 2                 83.623     µg/m3  2021-01-01 02:00:00 +01:00
# 3                 92.069     µg/m3  2021-01-01 03:00:00 +01:00
# 4                 62.599     µg/m3  2021-01-01 04:00:00 +01:00
# ...                  ...       ...                         ...
# 8756              13.676     µg/m3  2021-12-31 19:00:00 +01:00
# 8757              20.128     µg/m3  2021-12-31 20:00:00 +01:00
# 8758              20.175     µg/m3  2021-12-31 21:00:00 +01:00
# 8759              20.246     µg/m3  2021-12-31 22:00:00 +01:00
# 8760              13.501     µg/m3  2021-12-31 23:00:00 +01:00
#
#                      DatetimeEnd  PM2.5 Concentration PM2.5 Unit  \
# 0     2021-01-01 01:00:00 +01:00               38.201      µg/m3
# 1     2021-01-01 02:00:00 +01:00               73.851      µg/m3
# 2     2021-01-01 03:00:00 +01:00               86.836      µg/m3
# 3     2021-01-01 04:00:00 +01:00               84.249      µg/m3
# 4     2021-01-01 05:00:00 +01:00               52.598      µg/m3
# ...                          ...                  ...        ...
# 8756  2021-12-31 20:00:00 +01:00               17.344      µg/m3
# 8757  2021-12-31 21:00:00 +01:00               16.332      µg/m3
# 8758  2021-12-31 22:00:00 +01:00               26.282      µg/m3
# 8759  2021-12-31 23:00:00 +01:00               29.147      µg/m3
# 8760  2022-01-01 00:00:00 +01:00               18.311      µg/m3
#
#       CO Concentration CO Unit  NO2 Concentration NO2 Unit  SO2 Concentration  \
# 0             0.634172   mg/m3            47.6681    µg/m3           16.76170
# 1             0.710036   mg/m3            46.9415    µg/m3            9.96729
# 2             0.694492   mg/m3            43.2686    µg/m3           12.96940
# 3             0.517128   mg/m3            31.2688    µg/m3            5.39022
# 4             0.449384   mg/m3            20.7586    µg/m3            7.52647
# ...                ...     ...                ...      ...                ...
# 8756          0.478848   mg/m3            64.6772    µg/m3                NaN
# 8757          0.498800   mg/m3            64.6734    µg/m3            5.11811
# 8758          0.484764   mg/m3            58.2988    µg/m3            4.95531
# 8759          0.402288   mg/m3            48.8669    µg/m3            5.03139
# 8760          0.226896   mg/m3            25.8923    µg/m3            5.02713
#
#      SO2 Unit  C6H6 Concentration C6H6 Unit
# 0       µg/m3            1.918480     µg/m3
# 1       µg/m3            2.365350     µg/m3
# 2       µg/m3            2.808970     µg/m3
# 3       µg/m3            2.451150     µg/m3
# 4       µg/m3            1.701050     µg/m3
# ...       ...                 ...       ...
# 8756      NaN            1.606480     µg/m3
# 8757    µg/m3            1.327300     µg/m3
# 8758    µg/m3            1.443330     µg/m3
# 8759    µg/m3            1.365320     µg/m3
# 8760    µg/m3            0.736775     µg/m3
#
# [8761 rows x 14 columns]

# %%
df = df_2018
df = pd.concat([df, df_2019], ignore_index=True)
df = pd.concat([df, df_2020], ignore_index=True)
df = pd.concat([df, df_2021], ignore_index=True)
df
# Out:
#        PM10 Concentration PM10 Unit               DatetimeBegin  \
# 0                  38.942     µg/m3  2018-01-01 00:00:00 +01:00
# 1                  52.889     µg/m3  2018-01-01 01:00:00 +01:00
# 2                  37.007     µg/m3  2018-01-01 02:00:00 +01:00
# 3                  35.837     µg/m3  2018-01-01 03:00:00 +01:00
# 4                  34.408     µg/m3  2018-01-01 04:00:00 +01:00
# ...                   ...       ...                         ...
# 35061              13.676     µg/m3  2021-12-31 19:00:00 +01:00
# 35062              20.128     µg/m3  2021-12-31 20:00:00 +01:00
# 35063              20.175     µg/m3  2021-12-31 21:00:00 +01:00
# 35064              20.246     µg/m3  2021-12-31 22:00:00 +01:00
# 35065              13.501     µg/m3  2021-12-31 23:00:00 +01:00
#
#                       DatetimeEnd  PM2.5 Concentration PM2.5 Unit  \
# 0      2018-01-01 01:00:00 +01:00               46.409      µg/m3
# 1      2018-01-01 02:00:00 +01:00               53.467      µg/m3
# 2      2018-01-01 03:00:00 +01:00               37.668      µg/m3
# 3      2018-01-01 04:00:00 +01:00               37.333      µg/m3
# 4      2018-01-01 05:00:00 +01:00               29.130      µg/m3
# ...                           ...                  ...        ...
# 35061  2021-12-31 20:00:00 +01:00               17.344      µg/m3
# 35062  2021-12-31 21:00:00 +01:00               16.332      µg/m3
# 35063  2021-12-31 22:00:00 +01:00               26.282      µg/m3
# 35064  2021-12-31 23:00:00 +01:00               29.147      µg/m3
# 35065  2022-01-01 00:00:00 +01:00               18.311      µg/m3
#
#        CO Concentration CO Unit  NO2 Concentration NO2 Unit  \
# 0              0.461680   mg/m3            21.6056    µg/m3
# 1              0.432680   mg/m3            21.1869    µg/m3
# 2              0.392080   mg/m3            16.2845    µg/m3
# 3              0.386280   mg/m3            17.3246    µg/m3
# 4              0.363080   mg/m3            15.5656    µg/m3
# ...                 ...     ...                ...      ...
# 35061          0.478848   mg/m3            64.6772    µg/m3
# 35062          0.498800   mg/m3            64.6734    µg/m3
# 35063          0.484764   mg/m3            58.2988    µg/m3
# 35064          0.402288   mg/m3            48.8669    µg/m3
# 35065          0.226896   mg/m3            25.8923    µg/m3
#
#        SO2 Concentration SO2 Unit  C6H6 Concentration C6H6 Unit
# 0                5.36549    µg/m3            1.108250     µg/m3
# 1                    NaN      NaN            0.936000     µg/m3
# 2                5.14364    µg/m3            0.692250     µg/m3
# 3                5.16466    µg/m3            0.598000     µg/m3
# 4                5.23302    µg/m3            0.572000     µg/m3
# ...                  ...      ...                 ...       ...
# 35061                NaN      NaN            1.606480     µg/m3
# 35062            5.11811    µg/m3            1.327300     µg/m3
# 35063            4.95531    µg/m3            1.443330     µg/m3
# 35064            5.03139    µg/m3            1.365320     µg/m3
# 35065            5.02713    µg/m3            0.736775     µg/m3
#
# [35066 rows x 14 columns]

# %%
nan_rows = sum(df.apply(lambda x: sum(x.isnull().values), axis = 1) > 0)
print(f'Number of rows containing NaN is {nan_rows}/{len(df)} or {nan_rows / len(df) * 100}%')
df.to_csv('../data/interim/EEA-SK-Ba.csv', sep=',', encoding='utf-8', index=False)
# Out:
# Number of rows containing NaN is 4356/35066 or 12.422289397136828%
